# %% [markdown]
# ## Downloading the GFS0P25 Using WxData
#
# In this example, we will use WxData to download the full variable set of GFS0P25 data for the CONUS.
#
# WxData downloads, pre/post-processes and returns a the post-processed xarray.array to the user.
#
# **If you are getting SSL Certificate Errors when trying to download data, you may be using a proxy server connection**
#
# We will not be doing any proxy connection examples.
#
# How to set up a proxy:
#
# proxies (dict or None) - Default=None. If the user is using proxy server(s), the user must change the following:
#
#        proxies=None ---> proxies={
#                                'http':'http://your-proxy-address:port',
#                                'https':'http://your-proxy-address:port'
#                                }
#
# For more information on configuring proxies: https://requests.readthedocs.io/en/latest/user/advanced/#proxies
#
# CONUS Boundaries in this example:
#
#     west = -120
#     east = -65
#     south = 20
#     north = 50
#
# WxData is developed and maintained by Eric J. Drewitz
#
# (C) Eric J. Drewitz 2025-2026

# %% [markdown]
# ## Importing the `gfs_0p25` function from WxData
#
# Here are the default settings for `gfs_0p25`
#
#     def gfs_0p25(final_forecast_hour=384,
#                 western_bound=-180,
#                 eastern_bound=180,
#                 northern_bound=90,
#                 southern_bound=-90,
#                 step=3,
#                 process_data=True,
#                 proxies=None,
#                 variables=['geopotential height',
#                            'temperature',
#                            'relative humidity',
#                            'u-component of wind'
#                            'v-component of wind'],
#                 custom_directory=None,
#                 clear_recycle_bin=False,
#                 convert_temperature=True,
#                 convert_to='celsius',
#                 chunk_size=8192,
#                 notifications='off',
#                 clear_data=False,
#                 source='noaa',
#                 level_type='pressure',
#                 levels=[1000,
#                         925,
#                         850,
#                         700,
#                         500,
#                         400,
#                         300,
#                         250,
#                         200,
#                         100,
#                         50,
#                         10]):
#
# *Here is the docstring for these arguments:*
#
#     This function downloads GFS0P25 data and saves it to a folder.
#
#     Required Argumemnts: None
#
#     Optional Arguments:
#
#     1) final_forecast_hour (Integer) - Default = 384. The final forecast hour the user wishes to download. The GFS0P25
#     goes out to 384 hours. For those who wish to have a shorter dataset, they may set final_forecast_hour to a value lower than
#     384 by the nereast increment of 6 hours.
#
#     2) western_bound (Float or Integer) - Default=-180. The western bound of the data needed.
#
#     3) eastern_bound (Float or Integer) - Default=180. The eastern bound of the data needed.
#
#     4) northern_bound (Float or Integer) - Default=90. The northern bound of the data needed.
#
#     5) southern_bound (Float or Integer) - Default=-90. The southern bound of the data needed.
#
#     6) step (Integer) - Default=3. Set to 3 for 3hr increments and 6 for 6hrly increments.
#
#     7) process_data (Boolean) - Default=True. When set to True, WxData will preprocess the model data. If the user wishes to process the
#        data via their own external method, set process_data=False which means the data will be downloaded but not processed.
#
#     8) proxies (dict or None) - Default=None. If the user is using proxy server(s), the user must change the following:
#
#        proxies=None ---> proxies={
#                                'http':'http://your-proxy-address:port',
#                                'https':'http://your-proxy-address:port'
#                                }
#
#     9) variables (String List) - Default=['geopotential height',
#                                             'temperature',
#                                             'relative humidity',
#                                             'u-component of wind'
#                                             'v-component of wind']
#
#         The variables the user wishes to query.
#
#         Variables
#         ---------
#
#         'best lifted index'
#         'absolute vorticity'
#         'convective precipitation'
#         'albedo'
#         'total precipitation'
#         'convective available potential energy'
#         'categorical freezing rain'
#         'categorical ice pellets'
#         'convective inhibition'
#         'cloud mixing ratio'
#         'plant canopy surface water'
#         'percent frozen precipitaion'
#         'convective precipitation rate'
#         'categorical rain'
#         'categorical snow'
#         'cloud water'
#         'cloud work function'
#         'downward longwave radiation flux'
#         'dew point'
#         'downward shortwave radiation flux'
#         'vertical velocity (height)'
#         'field capacity'
#         'surface friction velocity'
#         'ground heat flux'
#         'graupel'
#         'wind gust'
#         'high cloud cover'
#         'geopotential height'
#         'haines index'
#         'storm relative helicity'
#         'planetary boundary layer height'
#         'icao standard atmosphere reference height'
#         'ice cover'
#         'ice growth rate'
#         'ice thickness'
#         'ice temperature'
#         'ice water mixing ratio'
#         'land cover'
#         'low cloud cover'
#         'surface lifted index'
#         'latent heat net flux'
#         'middle cloud cover'
#         'mean sea level pressure'
#         'mslp (eta model reduction)'
#         'ozone mixing ratio'
#         'potential evaporation rate'
#         'pressure level from which parcel was lifted'
#         'potential temperature'
#         'precipitation rate'
#         'pressure'
#         'mean sea level pressure'
#         'precipitable water'
#         'composite reflectivity'
#         'reflectivity'
#         'relative humidity'
#         'rain mixing ratio'
#         'surface roughness'
#         'sensible heat net flux'
#         'snow mixing ratio'
#         'snow depth'
#         'liquid volumetric soil moisture (non-frozen)'
#         'volumetric soil moisture content'
#         'soil type'
#         'specific humidity'
#         'sunshine duration'
#         'total cloud cover'
#         'maximum temperature'
#         'minimum temperature'
#         'temperature'
#         'total ozone'
#         'soil temperature'
#         'momentum flux (u-component)'
#         'u-component of wind'
#         'zonal flux of gravity wave stress'
#         'upward longwave radiation flux'
#         'u-component of storm motion'
#         'upward shortwave radiation flux'
#         'vegetation'
#         'momentum flux (v-component)'
#         'v-component of wind'
#         'meridional flux of gravity wave stress'
#         'visibility'
#         'ventilation rate'
#         'v-component of storm motion'
#         'vertical velocity (pressure)'
#         'vertical speed shear'
#         'water runoff'
#         'water equivalent of accumulated snow depth'
#         'wilting point'
#
#     10) custom_directory (String or None) - Default=None. If the user wishes to define their own directory to where the files are saved,
#         the user must pass in a string representing the path of the directory. Otherwise, the directory created by default in WxData will
#         be used.
#
#     11) clear_recycle_bin (Boolean) - (Default=False in WxData >= 1.2.5) (Default=True in WxData < 1.2.5). When set to True,
#         the contents in your recycle/trash bin will be deleted with each run of the program you are calling WxData.
#         This setting is to help preserve memory on the machine.
#
#     12) convert_temperature (Boolean) - Default=True. When set to True, the temperature related fields will be converted from Kelvin to
#         either Celsius or Fahrenheit. When False, this data remains in Kelvin.
#
#     13) convert_to (String) - Default='celsius'. When set to 'celsius' temperature related fields convert to Celsius.
#         Set convert_to='fahrenheit' for Fahrenheit.
#
#     14) custom_directory (String or None) - Default=None. The directory path where the ECMWF IFS Wave files will be saved to.
#         Default = f:ECMWF/IFS/WAVE
#
#     15) chunk_size (Integer) - Default=8192. The size of the chunks when writing the GRIB/NETCDF data to a file.
#
#     16) notifications (String) - Default='off'. Notification when a file is downloaded and saved to {path}
#
#     17) clear_data (Boolean) - Default=False. When set to False, the scanner safe-guard remains in place (recommended for most users).
#         When set to True, the scanner safe-guard is disabled and directory branch is cleared and new data is downloaded.
#
#     18) source (String) - Default='noaa'. The data server the user wants to connect the client to.
#
#         Server List
#         -----------
#
#         1) NOAA/NCEP/NOMADS - source='noaa'
#         2) Amazon AWS - source='aws'
#         3) Google Cloud - source='google'
#
#     19) level_type (String) - Default='pressure'. The type of level for the variable.
#
#         Level Types
#         -----------
#
#         'pressure'
#         'mean sea level'
#         'hybrid'
#         'entire atmosphere'
#         'boundary layer'
#         'low cloud layer'
#         'middle cloud layer'
#         'high cloud layer'
#         'convective cloud bottom level'
#         'low cloud bottom level'
#         'middle cloud bottom level'
#         'high cloud bottom level'
#         'convective cloud top level'
#         'low cloud top level'
#         'middle cloud top level'
#         'high cloud top level'
#         'convective cloud layer'
#         'tropopause'
#         'max wind'
#         'isothermal'
#         'highest tropospheric freezing level'
#         'height above ground'
#         'surface'
#         'height below ground'
#         'sigma layer'
#         'sigma level'
#         'entire atmosphere (considered as a single layer)'
#         'pressure above ground'
#         'potential vorticity surface'
#
#     20) levels (String, Integer or Float List) - Default=[1000,
#                                                             925,
#                                                             850,
#                                                             700,
#                                                             500,
#                                                             400,
#                                                             300,
#                                                             250,
#                                                             200,
#                                                             100,
#                                                             50,
#                                                             10]
#
#         The pressure, height or depth levels.
#
#     Returns
#     -------
#
#     An xarray.array dataset of the most recent GFS0P25 run.
#
#     Post-processed Variable Key List
#     --------------------------------
#
#     'surface_pressure'
#     'total_precipitation'
#     'categorical_snow'
#     'categorical_ice_pellets'
#     'categorical_freezing_rain'
#     'categorical_rain'
#     'time_mean_surface_latent_heat_flux'
#     'time_mean_surface_sensible_heat_flux'
#     'surface_downward_shortwave_radiation_flux'
#     'surface_downward_longwave_radiation_flux'
#     'surface_upward_shortwave_radiation_flux'
#     'surface_upward_longwave_radiation_flux'
#     'orography'
#     'water_equivalent_of_accumulated_snow_depth'
#     'snow_depth'
#     'sea_ice_thickness'
#     'surface_visibility'
#     'surface_wind_gust'
#     'percent_frozen_precipitation'
#     'convective_available_potential_energy'
#     'convective_inhibition'
#     'mslp'
#     'soil_temperature'
#     'volumetric_soil_moisture_content'
#     '2m_temperature'
#     '2m_relative_humidity'
#     '2m_dew_point'
#     'maximum_temperature'
#     'minimum_temperature'
#     '10m_u_wind_component'
#     '10m_v_wind_component'
#     'precipitable_water'
#     'mixed_layer_cape'
#     'mixed_layer_cin'
#     '3km_helicity'

# %%
from wxdata import gfs_0p25

# %%
"""
We first need to download our pressure-field parameters

Let's download the temperature in the bottom 500 mb:
variables=['temperature']
levels=[1000,
        925,
        850,
        700,
        500]

Let's also download our data from the Google Cloud rather than NOAA/NCEP/NOMADS

source='google'
"""

pressure = gfs_0p25(western_bound=-125, 
            eastern_bound=-65, 
            northern_bound=50, 
            southern_bound=20,
            source='google',
            variables=['temperature'],
            levels=[1000,
                    925,
                    850,
                    700,
                    500])
# Out:
# Downloading GFS0P25...
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.1k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.2k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/106k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/88.9k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.1k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/104k]
# TMP @ 500 mb                   |                              |   0% [0.00/88.7k]
# TMP @ 700 mb                   |                              |   0% [0.00/93.7k]
# TMP @ 850 mb                   |                              |   0% [0.00/103k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/104k]
# TMP @ 500 mb                   |                              |   0% [0.00/88.8k]
# TMP @ 700 mb                   |                              |   0% [0.00/93.0k]
# TMP @ 850 mb                   |                              |   0% [0.00/103k]
# TMP @ 925 mb                   |                              |   0% [0.00/104k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/104k]
# TMP @ 500 mb                   |                              |   0% [0.00/88.7k]
# TMP @ 700 mb                   |                              |   0% [0.00/92.9k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/104k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/88.8k]
# TMP @ 700 mb                   |                              |   0% [0.00/93.1k]
# TMP @ 850 mb                   |                              |   0% [0.00/103k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/88.8k]
# TMP @ 700 mb                   |                              |   0% [0.00/93.4k]
# TMP @ 850 mb                   |                              |   0% [0.00/103k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/88.8k]
# TMP @ 700 mb                   |                              |   0% [0.00/93.8k]
# TMP @ 850 mb                   |                              |   0% [0.00/103k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/88.8k]
# TMP @ 700 mb                   |                              |   0% [0.00/93.7k]
# TMP @ 850 mb                   |                              |   0% [0.00/103k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/88.6k]
# TMP @ 700 mb                   |                              |   0% [0.00/93.1k]
# TMP @ 850 mb                   |                              |   0% [0.00/102k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/104k]
# TMP @ 500 mb                   |                              |   0% [0.00/88.3k]
# TMP @ 700 mb                   |                              |   0% [0.00/92.8k]
# TMP @ 850 mb                   |                              |   0% [0.00/103k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/104k]
# TMP @ 500 mb                   |                              |   0% [0.00/88.2k]
# TMP @ 700 mb                   |                              |   0% [0.00/92.6k]
# TMP @ 850 mb                   |                              |   0% [0.00/103k]
# TMP @ 925 mb                   |                              |   0% [0.00/104k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/104k]
# TMP @ 500 mb                   |                              |   0% [0.00/88.1k]
# TMP @ 700 mb                   |                              |   0% [0.00/92.6k]
# TMP @ 850 mb                   |                              |   0% [0.00/103k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/88.3k]
# TMP @ 700 mb                   |                              |   0% [0.00/92.9k]
# TMP @ 850 mb                   |                              |   0% [0.00/103k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/88.6k]
# TMP @ 700 mb                   |                              |   0% [0.00/93.6k]
# TMP @ 850 mb                   |                              |   0% [0.00/103k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/88.4k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.1k]
# TMP @ 850 mb                   |                              |   0% [0.00/103k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/106k]
# TMP @ 500 mb                   |                              |   0% [0.00/88.6k]
# TMP @ 700 mb                   |                              |   0% [0.00/93.8k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.1k]
# TMP @ 700 mb                   |                              |   0% [0.00/93.8k]
# TMP @ 850 mb                   |                              |   0% [0.00/103k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.0k]
# TMP @ 700 mb                   |                              |   0% [0.00/93.6k]
# TMP @ 850 mb                   |                              |   0% [0.00/103k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/88.5k]
# TMP @ 700 mb                   |                              |   0% [0.00/93.6k]
# TMP @ 850 mb                   |                              |   0% [0.00/103k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/88.6k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.2k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/88.8k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.4k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.0k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.8k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/106k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.7k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.7k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/106k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/106k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.4k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.4k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/106k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.4k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.2k]
# TMP @ 850 mb                   |                              |   0% [0.00/103k]
# TMP @ 925 mb                   |                              |   0% [0.00/106k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.8k]
# TMP @ 700 mb                   |                              |   0% [0.00/93.9k]
# TMP @ 850 mb                   |                              |   0% [0.00/103k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.6k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.1k]
# TMP @ 850 mb                   |                              |   0% [0.00/103k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.1k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.1k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.3k]
# TMP @ 700 mb                   |                              |   0% [0.00/93.8k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.9k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.3k]
# TMP @ 850 mb                   |                              |   0% [0.00/103k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.7k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.8k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/106k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/106k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.7k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.9k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/106k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.7k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.7k]
# TMP @ 850 mb                   |                              |   0% [0.00/103k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/104k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.9k]
# TMP @ 700 mb                   |                              |   0% [0.00/93.7k]
# TMP @ 850 mb                   |                              |   0% [0.00/103k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/104k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.1k]
# TMP @ 700 mb                   |                              |   0% [0.00/93.4k]
# TMP @ 850 mb                   |                              |   0% [0.00/103k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/104k]
# TMP @ 500 mb                   |                              |   0% [0.00/88.8k]
# TMP @ 700 mb                   |                              |   0% [0.00/93.3k]
# TMP @ 850 mb                   |                              |   0% [0.00/103k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/104k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.3k]
# TMP @ 700 mb                   |                              |   0% [0.00/93.4k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/104k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.4k]
# TMP @ 700 mb                   |                              |   0% [0.00/93.8k]
# TMP @ 850 mb                   |                              |   0% [0.00/103k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.6k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.4k]
# TMP @ 850 mb                   |                              |   0% [0.00/103k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.6k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.2k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/104k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.2k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.1k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/104k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.5k]
# TMP @ 700 mb                   |                              |   0% [0.00/93.4k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/104k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.2k]
# TMP @ 700 mb                   |                              |   0% [0.00/93.2k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/104k]
# TMP @ 500 mb                   |                              |   0% [0.00/88.5k]
# TMP @ 700 mb                   |                              |   0% [0.00/93.2k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.2k]
# TMP @ 700 mb                   |                              |   0% [0.00/93.5k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.3k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.1k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/106k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.1k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.7k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/106k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/106k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.1k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.6k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/106k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/106k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.0k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.1k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/106k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.0k]
# TMP @ 700 mb                   |                              |   0% [0.00/93.9k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/106k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/88.9k]
# TMP @ 700 mb                   |                              |   0% [0.00/93.6k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/106k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/88.7k]
# TMP @ 700 mb                   |                              |   0% [0.00/93.8k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/106k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.3k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.0k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/106k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/88.9k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.5k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/106k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.6k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.5k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/106k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/106k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.2k]
# TMP @ 700 mb                   |                              |   0% [0.00/95.0k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/106k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.3k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.2k]
# TMP @ 850 mb                   |                              |   0% [0.00/103k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/104k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.1k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.3k]
# TMP @ 850 mb                   |                              |   0% [0.00/103k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/104k]
# TMP @ 500 mb                   |                              |   0% [0.00/88.9k]
# TMP @ 700 mb                   |                              |   0% [0.00/93.6k]
# TMP @ 850 mb                   |                              |   0% [0.00/103k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/104k]
# TMP @ 500 mb                   |                              |   0% [0.00/88.7k]
# TMP @ 700 mb                   |                              |   0% [0.00/93.7k]
# TMP @ 850 mb                   |                              |   0% [0.00/103k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/88.7k]
# TMP @ 700 mb                   |                              |   0% [0.00/93.9k]
# TMP @ 850 mb                   |                              |   0% [0.00/103k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.0k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.3k]
# TMP @ 850 mb                   |                              |   0% [0.00/103k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/106k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.7k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.8k]
# TMP @ 850 mb                   |                              |   0% [0.00/103k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.5k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.2k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/106k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.5k]
# TMP @ 700 mb                   |                              |   0% [0.00/93.9k]
# TMP @ 850 mb                   |                              |   0% [0.00/103k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/104k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.2k]
# TMP @ 700 mb                   |                              |   0% [0.00/93.8k]
# TMP @ 850 mb                   |                              |   0% [0.00/103k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/104k]
# TMP @ 500 mb                   |                              |   0% [0.00/88.8k]
# TMP @ 700 mb                   |                              |   0% [0.00/93.3k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/104k]
# TMP @ 500 mb                   |                              |   0% [0.00/88.7k]
# TMP @ 700 mb                   |                              |   0% [0.00/93.4k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/60.5k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.4k]
# TMP @ 700 mb                   |                              |   0% [0.00/93.5k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/60.3k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.5k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.7k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/60.8k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.2k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.7k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.4k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.6k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.6k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.4k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/104k]
# TMP @ 500 mb                   |                              |   0% [0.00/88.9k]
# TMP @ 700 mb                   |                              |   0% [0.00/93.6k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/104k]
# TMP @ 500 mb                   |                              |   0% [0.00/88.7k]
# TMP @ 700 mb                   |                              |   0% [0.00/93.5k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/60.1k]
# TMP @ 500 mb                   |                              |   0% [0.00/88.7k]
# TMP @ 700 mb                   |                              |   0% [0.00/93.5k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/60.4k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.3k]
# TMP @ 700 mb                   |                              |   0% [0.00/93.7k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/60.6k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.8k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.3k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/61.0k]
# TMP @ 500 mb                   |                              |   0% [0.00/90.0k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.7k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/106k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/106k]
# TMP @ 500 mb                   |                              |   0% [0.00/90.1k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.3k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/106k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/106k]
# TMP @ 500 mb                   |                              |   0% [0.00/90.1k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.3k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/106k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/89.6k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.0k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/106k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/90.0k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.0k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/106k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/60.8k]
# TMP @ 500 mb                   |                              |   0% [0.00/90.1k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.9k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/106k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/106k]
# TMP @ 500 mb                   |                              |   0% [0.00/90.5k]
# TMP @ 700 mb                   |                              |   0% [0.00/95.7k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/107k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/90.4k]
# TMP @ 700 mb                   |                              |   0% [0.00/95.0k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/106k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/90.3k]
# TMP @ 700 mb                   |                              |   0% [0.00/94.9k]
# TMP @ 850 mb                   |                              |   0% [0.00/105k]
# TMP @ 925 mb                   |                              |   0% [0.00/106k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/60.6k]
# TMP @ 500 mb                   |                              |   0% [0.00/90.9k]
# TMP @ 700 mb                   |                              |   0% [0.00/95.6k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/106k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/106k]
# TMP @ 500 mb                   |                              |   0% [0.00/91.2k]
# TMP @ 700 mb                   |                              |   0% [0.00/95.9k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/106k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/91.4k]
# TMP @ 700 mb                   |                              |   0% [0.00/95.1k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/106k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/90.6k]
# TMP @ 700 mb                   |                              |   0% [0.00/95.1k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/105k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/60.5k]
# TMP @ 500 mb                   |                              |   0% [0.00/91.4k]
# TMP @ 700 mb                   |                              |   0% [0.00/95.9k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/106k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/106k]
# TMP @ 500 mb                   |                              |   0% [0.00/91.1k]
# TMP @ 700 mb                   |                              |   0% [0.00/95.8k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/107k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/105k]
# TMP @ 500 mb                   |                              |   0% [0.00/91.2k]
# TMP @ 700 mb                   |                              |   0% [0.00/95.2k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/106k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/60.1k]
# TMP @ 500 mb                   |                              |   0% [0.00/90.5k]
# TMP @ 700 mb                   |                              |   0% [0.00/95.2k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/106k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/60.5k]
# TMP @ 500 mb                   |                              |   0% [0.00/91.3k]
# TMP @ 700 mb                   |                              |   0% [0.00/95.7k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/106k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/60.9k]
# TMP @ 500 mb                   |                              |   0% [0.00/91.1k]
# TMP @ 700 mb                   |                              |   0% [0.00/95.6k]
# TMP @ 850 mb                   |                              |   0% [0.00/105k]
# TMP @ 925 mb                   |                              |   0% [0.00/106k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/60.2k]
# TMP @ 500 mb                   |                              |   0% [0.00/90.7k]
# TMP @ 700 mb                   |                              |   0% [0.00/95.2k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/106k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/60.1k]
# TMP @ 500 mb                   |                              |   0% [0.00/90.4k]
# TMP @ 700 mb                   |                              |   0% [0.00/95.1k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/59.8k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/60.2k]
# TMP @ 500 mb                   |                              |   0% [0.00/90.8k]
# TMP @ 700 mb                   |                              |   0% [0.00/95.6k]
# TMP @ 850 mb                   |                              |   0% [0.00/59.0k]
# TMP @ 925 mb                   |                              |   0% [0.00/60.4k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/60.5k]
# TMP @ 500 mb                   |                              |   0% [0.00/91.6k]
# TMP @ 700 mb                   |                              |   0% [0.00/95.7k]
# TMP @ 850 mb                   |                              |   0% [0.00/105k]
# TMP @ 925 mb                   |                              |   0% [0.00/60.9k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/59.8k]
# TMP @ 500 mb                   |                              |   0% [0.00/90.7k]
# TMP @ 700 mb                   |                              |   0% [0.00/95.1k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/60.5k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/59.9k]
# TMP @ 500 mb                   |                              |   0% [0.00/90.2k]
# TMP @ 700 mb                   |                              |   0% [0.00/95.1k]
# TMP @ 850 mb                   |                              |   0% [0.00/104k]
# TMP @ 925 mb                   |                              |   0% [0.00/50.1k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/60.4k]
# TMP @ 500 mb                   |                              |   0% [0.00/90.6k]
# TMP @ 700 mb                   |                              |   0% [0.00/95.8k]
# TMP @ 850 mb                   |                              |   0% [0.00/59.5k]
# TMP @ 925 mb                   |                              |   0% [0.00/60.7k]
# Writing GRIB messages     |                              | 0/5
# TMP @ 1000 mb                  |                              |   0% [0.00/60.7k]
# TMP @ 500 mb                   |                              |   0% [0.00/90.8k]
# TMP @ 700 mb                   |                              |   0% [0.00/95.6k]
# TMP @ 850 mb                   |                              |   0% [0.00/59.4k]
# TMP @ 925 mb                   |                              |   0% [0.00/60.7k]
# GFS0P25 Download Complete
# GFS0P25 Data Processing...
# GFS0P25 Data Processing Complete.

# %%
pressure
# Out:
# <xarray.Dataset> Size: 61MB
# Dimensions:        (step: 105, isobaricInhPa: 5, latitude: 121, longitude: 241)
# Coordinates:
#   * step           (step) float64 840B 0.0 3.0 6.0 9.0 ... 372.0 378.0 384.0
#   * isobaricInhPa  (isobaricInhPa) float64 40B 1e+03 925.0 850.0 700.0 500.0
#   * latitude       (latitude) float64 968B 50.0 49.75 49.5 ... 20.5 20.25 20.0
#   * longitude      (longitude) float64 2kB -125.0 -124.8 -124.5 ... -65.25 -65.0
#     time           datetime64[ns] 8B ...
#     valid_time     datetime64[ns] 8B ...
# Data variables:
#     temperature    (step, isobaricInhPa, latitude, longitude) float32 61MB dask.array<chunksize=(1, 5, 121, 241), meta=np.ndarray>
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2026-05-17T18:15 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
"""
We now need to download our surface pressure
level_type='surface'
variables=['mean sea level pressure']
levels=None

Also need to set clear_data=True to bypass skipping the download.
"""

surface = gfs_0p25(western_bound=-125, 
            eastern_bound=-65, 
            northern_bound=50, 
            southern_bound=20,
            level_type='mean sea level',
            source='google',
            clear_data=True,
            variables=['mean sea level pressure'],
            levels=None)
# Out:
# Downloading GFS0P25...
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/122k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/122k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/122k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/122k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/122k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/122k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/122k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/122k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/122k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/122k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/122k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/122k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/122k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/122k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/122k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/122k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/122k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/122k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/122k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/122k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/122k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/122k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/122k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/122k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/122k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/122k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/122k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/122k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/122k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/122k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/122k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/122k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/122k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/122k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/122k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/122k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/122k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/122k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/122k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/108k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/108k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/108k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/108k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/107k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/107k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/107k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/124k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/124k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/124k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/124k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/128k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/128k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/124k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/128k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/128k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/123k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/108k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/122k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/108k]
# Writing GRIB messages     |                              | 0/1
# PRMSL @ mean sea level         |                              |   0% [0.00/108k]
# GFS0P25 Download Complete
# GFS0P25 Data Processing...
# GFS0P25 Data Processing Complete.

# %%
surface
# Out:
# <xarray.Dataset> Size: 12MB
# Dimensions:     (step: 105, latitude: 121, longitude: 241)
# Coordinates:
#   * step        (step) float64 840B 0.0 3.0 6.0 9.0 ... 366.0 372.0 378.0 384.0
#   * latitude    (latitude) float64 968B 50.0 49.75 49.5 ... 20.5 20.25 20.0
#   * longitude   (longitude) float64 2kB -125.0 -124.8 -124.5 ... -65.25 -65.0
#     time        datetime64[ns] 8B ...
#     meanSea     float64 8B ...
#     valid_time  datetime64[ns] 8B ...
# Data variables:
#     mslp        (step, latitude, longitude) float32 12MB dask.array<chunksize=(1, 121, 241), meta=np.ndarray>
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2026-05-17T18:17 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
# Merge the pressure with surface data into one dataset
ds = pressure
ds['mslp'] = surface['mslp']

# %%
ds
# Out:
# <xarray.Dataset> Size: 73MB
# Dimensions:        (step: 105, isobaricInhPa: 5, latitude: 121, longitude: 241)
# Coordinates:
#   * step           (step) float64 840B 0.0 3.0 6.0 9.0 ... 372.0 378.0 384.0
#   * isobaricInhPa  (isobaricInhPa) float64 40B 1e+03 925.0 850.0 700.0 500.0
#   * latitude       (latitude) float64 968B 50.0 49.75 49.5 ... 20.5 20.25 20.0
#   * longitude      (longitude) float64 2kB -125.0 -124.8 -124.5 ... -65.25 -65.0
#     time           datetime64[ns] 8B ...
#     valid_time     datetime64[ns] 8B ...
#     meanSea        float64 8B ...
# Data variables:
#     temperature    (step, isobaricInhPa, latitude, longitude) float32 61MB dask.array<chunksize=(1, 5, 121, 241), meta=np.ndarray>
#     mslp           (step, latitude, longitude) float32 12MB dask.array<chunksize=(1, 121, 241), meta=np.ndarray>
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2026-05-17T18:15 GRIB to CDM+CF via cfgrib-0.9.1...

# %% [markdown]
# ## An Important Feature
#
# In order to prevent users who are newer to downloading data in a Python script, WxData has some safeguards.
#
# A scanner is in place to scan for the latest data on the server and locally on your PC.
#
# This scanner determines if the data is up to date.
#
# If the data is *not* up to date, the new dataset will be downloaded.
#
# If the data *is* up to date, the download will be skipped and post-processing will automatically begin.
#
# Let's demonstrate this safeguard by trying to download the data again.

# %%
pressure = gfs_0p25(western_bound=-125, 
            eastern_bound=-65, 
            northern_bound=50, 
            southern_bound=20,
            source='google',
            variables=['temperature'],
            levels=[1000,
                    925,
                    850,
                    700,
                    500])
# Out:
# GFS0P25 Data is up to date. Skipping download...
# GFS0P25 Data Processing...
# GFS0P25 Data Processing Complete.

# %%
pressure
# Out:
# <xarray.Dataset> Size: 12MB
# Dimensions:     (step: 105, latitude: 121, longitude: 241)
# Coordinates:
#   * step        (step) float64 840B 0.0 3.0 6.0 9.0 ... 366.0 372.0 378.0 384.0
#   * latitude    (latitude) float64 968B 50.0 49.75 49.5 ... 20.5 20.25 20.0
#   * longitude   (longitude) float64 2kB -125.0 -124.8 -124.5 ... -65.25 -65.0
#     time        datetime64[ns] 8B ...
#     meanSea     float64 8B ...
#     valid_time  datetime64[ns] 8B ...
# Data variables:
#     mslp        (step, latitude, longitude) float32 12MB dask.array<chunksize=(1, 121, 241), meta=np.ndarray>
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2026-05-17T18:17 GRIB to CDM+CF via cfgrib-0.9.1...

# %% [markdown]
# ## Pixel Queries
#
# Now let's demonstrate using WxData to perform a pixel query on the data.
#
# We can pixel query using a Station ID or a lat/lon.
#
# The WxData `pixel_query` function queries for the nearest gridpoint in the GRIB/netCDF file to the coordinates specified by the user.
#
# Let's now demonstrate both methods of using a pixel query.
#
#     1) Pixel Query for Ontario International Airport (Ontario, California) [KONT]
#     2) Pixel Query the latitude and longitude of East Northport, NY.
#
# When pixel querying using lat/lon coordinates, coordinates must be in decimal degrees!

# %% [markdown]
# ## Importing the `pixel_query` function from WxData
#
# Here are the default settings for `pixel_query`
#
#     def pixel_query(ds,
#                     latitude=None,
#                     longitude=None,
#                     station_id=None,
#                     coord_names=['latitude',
#                                 'longitude']):
#
# *Here is the docstring for these arguments:*
#
#     This function queries for the nearest pixel to a user specified point of (latitude/longitude).
#
#     This function is useful for people interested in a point forecast.
#
#     Applications include
#     ---------------------
#
#     1) forecast soundings
#
#     2) forecast meteograms
#
#     3) forecast time cross-sections
#
#     Required Arguments:
#
#     1) ds (xarray.array) - The forecast model dataset in GRIB format.
#
#     Optional Arguments:
#
#     1) station_id (String) - Default=None. The 4 letter station ID of an ASOS station.
#
#     2) latitude (Float) - Default=None. The latitude of the point in decimal degrees.
#
#     3) longitude (Float) - Default=None. The longitude of the point in decimal degrees.
#
#     4) coord_names (String List) - Default=['latitude', 'longitude'] A list of the coordinate names (i.e. 'longitude/latitude', 'lon'/'lat', 'easting'/'northing')
#
#     Returns
#     -------
#
#     An xarray.array for the pixel closest to the user specified coordinates or ASOS station.

# %%
from wxdata import pixel_query

# %%
ontario_ca = pixel_query(ds,
                         station_id='kont')

# %%
ontario_ca
# Out:
# <xarray.Dataset> Size: 3kB
# Dimensions:        (step: 105, isobaricInhPa: 5)
# Coordinates:
#   * step           (step) float64 840B 0.0 3.0 6.0 9.0 ... 372.0 378.0 384.0
#   * isobaricInhPa  (isobaricInhPa) float64 40B 1e+03 925.0 850.0 700.0 500.0
#     time           datetime64[ns] 8B 2026-05-17T18:00:00
#     latitude       float64 8B 34.0
#     valid_time     datetime64[ns] 8B 2026-05-17T18:00:00
#     longitude      float64 8B -117.5
#     meanSea        float64 8B 0.0
#     metpy_crs      object 8B Projection: latitude_longitude
# Data variables:
#     temperature    (step, isobaricInhPa) float32 2kB dask.array<chunksize=(1, 5), meta=np.ndarray>
#     mslp           (step) float32 420B dask.array<chunksize=(1,), meta=np.ndarray>
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2026-05-17T18:15 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
east_northport_ny = pixel_query(ds,
                                latitude=40.8792,
                                longitude=-73.3242)

# %%
east_northport_ny
# Out:
# <xarray.Dataset> Size: 3kB
# Dimensions:        (step: 105, isobaricInhPa: 5)
# Coordinates:
#   * step           (step) float64 840B 0.0 3.0 6.0 9.0 ... 372.0 378.0 384.0
#   * isobaricInhPa  (isobaricInhPa) float64 40B 1e+03 925.0 850.0 700.0 500.0
#     time           datetime64[ns] 8B 2026-05-17T18:00:00
#     latitude       float64 8B 41.0
#     valid_time     datetime64[ns] 8B 2026-05-17T18:00:00
#     longitude      float64 8B -73.25
#     meanSea        float64 8B 0.0
#     metpy_crs      object 8B Projection: latitude_longitude
# Data variables:
#     temperature    (step, isobaricInhPa) float32 2kB dask.array<chunksize=(1, 5), meta=np.ndarray>
#     mslp           (step) float32 420B dask.array<chunksize=(1,), meta=np.ndarray>
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2026-05-17T18:15 GRIB to CDM+CF via cfgrib-0.9.1...

# %% [markdown]
# ## Line Queries
#
# Some users might want to create graphics showing a cross-section of the model data.
#
# Users who wish to create cross-sections need to use the `line_query` function in WxData
#
# In this example, let's do an E to W line query from Los Angeles to NYC

# %% [markdown]
# ## Importing the `line_query` function from WxData
#
# Here are the default settings for `line_query`
#
#     def line_query(ds,
#                starting_point,
#                ending_point,
#                coord_names=['latitude',
#                             'longitude'],
#                surface_pressure_key='surface_pressure',
#                north_to_south=False,
#                pressure_level_key='isobaricInhPa'):
#
# *Here is the docstring for these arguments:*
#
#     This function is to query for a line that connects a starting_point (A) with an ending_point (B)
#
#     Applications Include
#     --------------------
#
#     1) Forecast cross-sections between two different geographical points.
#
#     Required Arguments:
#
#     1) ds (xarray.array) - The forecast model dataset in GRIB format.
#
#     2) starting_point (String or Tuple) - The starting point of the line.
#
#        The user has two options, either enter an ASOS station identifier as a string OR custom (lat, lon) in decimal degrees as a tuple.
#
#     3) ending_point (String or Tuple) - The ending point of the line.
#
#        The user has two options, either enter an ASOS station identifier as a string OR custom (lat, lon) in decimal degrees as a tuple.
#
#     Optional Arguments:
#
#     1) coord_names (String List) - Default=['latitude', 'longitude'] A list of the coordinate names (i.e. 'longitude/latitude', 'lon'/'lat', 'easting'/'northing')
#
#     2) surface_pressure_key (String) - Default='surface_pressure'. The variable key for surface pressure.
#
#     3) north_to_south (Boolean) - Default=False. When set to False, lines will better reflect a more E to W oriented cross section.
#        When True, lines will better reflect a more N to S oriented cross section.
#
#     4) pressure_level_key (String) - Default='isobaricInhPa'. The key for the pressure level.
#
#
#     Returns
#     -------
#
#     5 xarray.array data arrays of pixels along a line between points A and B.
#
#     1) ds_grid - The gridded variables.
#
#     2) pressure - The array of pressure levels.
#
#     3) index - The indexed point number for each point along the line.
#
#     4) lon - Array of longitude.
#
#     5) height - Array of height levels.

# %%
from wxdata import line_query

# %%
data = line_query(ds,
                  starting_point=(34.05,-118.24),
                  ending_point=(40.705,-73.975),
                 surface_pressure_key='mslp')

# %%
data
# Out:
# (<xarray.Dataset> Size: 423kB
#  Dimensions:        (step: 105, isobaricInhPa: 5, index: 100)
#  Coordinates:
#    * step           (step) float64 840B 0.0 3.0 6.0 9.0 ... 372.0 378.0 384.0
#    * isobaricInhPa  (isobaricInhPa) float64 40B 1e+03 925.0 850.0 700.0 500.0
#    * index          (index) int64 800B 0 1 2 3 4 5 6 7 ... 93 94 95 96 97 98 99
#      longitude      (index) float64 800B -118.2 -117.8 -117.4 ... -74.45 -73.97
#      latitude       (index) float64 800B 34.05 34.2 34.34 ... 40.75 40.73 40.7
#      time           datetime64[ns] 8B 2026-05-17T18:00:00
#      valid_time     datetime64[ns] 8B 2026-05-17T18:00:00
#      meanSea        float64 8B 0.0
#      metpy_crs      object 8B Projection: latitude_longitude
#  Data variables:
#      temperature    (step, isobaricInhPa, index) float32 210kB dask.array<chunksize=(1, 5, 100), meta=np.ndarray>
#      mslp           (step, isobaricInhPa, index) float32 210kB dask.array<chunksize=(1, 5, 100), meta=np.ndarray>
#  Attributes:
#      GRIB_edition:            2
#      GRIB_centre:             kwbc
#      GRIB_centreDescription:  US National Weather Service - NCEP
#      GRIB_subCentre:          0
#      Conventions:             CF-1.7
#      institution:             US National Weather Service - NCEP
#      history:                 2026-05-17T18:15 GRIB to CDM+CF via cfgrib-0.9.1...,
#  <xarray.DataArray 'isobaricInhPa' (step: 105, isobaricInhPa: 5, index: 100)> Size: 420kB
#  array([[[1000., 1000., 1000., ..., 1000., 1000., 1000.],
#          [ 925.,  925.,  925., ...,  925.,  925.,  925.],
#          [ 850.,  850.,  850., ...,  850.,  850.,  850.],
#          [ 700.,  700.,  700., ...,  700.,  700.,  700.],
#          [ 500.,  500.,  500., ...,  500.,  500.,  500.]],
#
#         [[1000., 1000., 1000., ..., 1000., 1000., 1000.],
#          [ 925.,  925.,  925., ...,  925.,  925.,  925.],
#          [ 850.,  850.,  850., ...,  850.,  850.,  850.],
#          [ 700.,  700.,  700., ...,  700.,  700.,  700.],
#          [ 500.,  500.,  500., ...,  500.,  500.,  500.]],
#
#         [[1000., 1000., 1000., ..., 1000., 1000., 1000.],
#          [ 925.,  925.,  925., ...,  925.,  925.,  925.],
#          [ 850.,  850.,  850., ...,  850.,  850.,  850.],
#          [ 700.,  700.,  700., ...,  700.,  700.,  700.],
#          [ 500.,  500.,  500., ...,  500.,  500.,  500.]],
#
#         ...,
#
#         [[1000., 1000., 1000., ..., 1000., 1000., 1000.],
#          [ 925.,  925.,  925., ...,  925.,  925.,  925.],
#          [ 850.,  850.,  850., ...,  850.,  850.,  850.],
#          [ 700.,  700.,  700., ...,  700.,  700.,  700.],
#          [ 500.,  500.,  500., ...,  500.,  500.,  500.]],
#
#         [[1000., 1000., 1000., ..., 1000., 1000., 1000.],
#          [ 925.,  925.,  925., ...,  925.,  925.,  925.],
#          [ 850.,  850.,  850., ...,  850.,  850.,  850.],
#          [ 700.,  700.,  700., ...,  700.,  700.,  700.],
#          [ 500.,  500.,  500., ...,  500.,  500.,  500.]],
#
#         [[1000., 1000., 1000., ..., 1000., 1000., 1000.],
#          [ 925.,  925.,  925., ...,  925.,  925.,  925.],
#          [ 850.,  850.,  850., ...,  850.,  850.,  850.],
#          [ 700.,  700.,  700., ...,  700.,  700.,  700.],
#          [ 500.,  500.,  500., ...,  500.,  500.,  500.]]],
#        shape=(105, 5, 100))
#  Coordinates:
#    * step           (step) float64 840B 0.0 3.0 6.0 9.0 ... 372.0 378.0 384.0
#    * isobaricInhPa  (isobaricInhPa) float64 40B 1e+03 925.0 850.0 700.0 500.0
#    * index          (index) int64 800B 0 1 2 3 4 5 6 7 ... 93 94 95 96 97 98 99
#      time           datetime64[ns] 8B 2026-05-17T18:00:00
#      valid_time     datetime64[ns] 8B 2026-05-17T18:00:00
#      meanSea        float64 8B 0.0
#      metpy_crs      object 8B Projection: latitude_longitude
#  Attributes:
#      long_name:         pressure
#      units:             hPa
#      positive:          down
#      stored_direction:  decreasing
#      standard_name:     air_pressure
#      _metpy_axis:       vertical,
#  <xarray.DataArray 'index' (step: 105, isobaricInhPa: 5, index: 100)> Size: 420kB
#  array([[[ 0,  1,  2, ..., 97, 98, 99],
#          [ 0,  1,  2, ..., 97, 98, 99],
#          [ 0,  1,  2, ..., 97, 98, 99],
#          [ 0,  1,  2, ..., 97, 98, 99],
#          [ 0,  1,  2, ..., 97, 98, 99]],
#
#         [[ 0,  1,  2, ..., 97, 98, 99],
#          [ 0,  1,  2, ..., 97, 98, 99],
#          [ 0,  1,  2, ..., 97, 98, 99],
#          [ 0,  1,  2, ..., 97, 98, 99],
#          [ 0,  1,  2, ..., 97, 98, 99]],
#
#         [[ 0,  1,  2, ..., 97, 98, 99],
#          [ 0,  1,  2, ..., 97, 98, 99],
#          [ 0,  1,  2, ..., 97, 98, 99],
#          [ 0,  1,  2, ..., 97, 98, 99],
#          [ 0,  1,  2, ..., 97, 98, 99]],
#
#         ...,
#
#         [[ 0,  1,  2, ..., 97, 98, 99],
#          [ 0,  1,  2, ..., 97, 98, 99],
#          [ 0,  1,  2, ..., 97, 98, 99],
#          [ 0,  1,  2, ..., 97, 98, 99],
#          [ 0,  1,  2, ..., 97, 98, 99]],
#
#         [[ 0,  1,  2, ..., 97, 98, 99],
#          [ 0,  1,  2, ..., 97, 98, 99],
#          [ 0,  1,  2, ..., 97, 98, 99],
#          [ 0,  1,  2, ..., 97, 98, 99],
#          [ 0,  1,  2, ..., 97, 98, 99]],
#
#         [[ 0,  1,  2, ..., 97, 98, 99],
#          [ 0,  1,  2, ..., 97, 98, 99],
#          [ 0,  1,  2, ..., 97, 98, 99],
#          [ 0,  1,  2, ..., 97, 98, 99],
#          [ 0,  1,  2, ..., 97, 98, 99]]], shape=(105, 5, 100))
#  Coordinates:
#    * step           (step) float64 840B 0.0 3.0 6.0 9.0 ... 372.0 378.0 384.0
#    * isobaricInhPa  (isobaricInhPa) float64 40B 1e+03 925.0 850.0 700.0 500.0
#    * index          (index) int64 800B 0 1 2 3 4 5 6 7 ... 93 94 95 96 97 98 99
#      longitude      (index) float64 800B -118.2 -117.8 -117.4 ... -74.45 -73.97
#      latitude       (index) float64 800B 34.05 34.2 34.34 ... 40.75 40.73 40.7
#      time           datetime64[ns] 8B 2026-05-17T18:00:00
#      valid_time     datetime64[ns] 8B 2026-05-17T18:00:00
#      meanSea        float64 8B 0.0
#      metpy_crs      object 8B Projection: latitude_longitude,
#  <xarray.DataArray 'longitude' (step: 105, isobaricInhPa: 5, index: 100)> Size: 420kB
#  array([[[-118.24      , -117.84495816, -117.44856076, ...,
#            -74.91710675,  -74.44590111,  -73.975     ],
#          [-118.24      , -117.84495816, -117.44856076, ...,
#            -74.91710675,  -74.44590111,  -73.975     ],
#          [-118.24      , -117.84495816, -117.44856076, ...,
#            -74.91710675,  -74.44590111,  -73.975     ],
#          [-118.24      , -117.84495816, -117.44856076, ...,
#            -74.91710675,  -74.44590111,  -73.975     ],
#          [-118.24      , -117.84495816, -117.44856076, ...,
#            -74.91710675,  -74.44590111,  -73.975     ]],
#
#         [[-118.24      , -117.84495816, -117.44856076, ...,
#            -74.91710675,  -74.44590111,  -73.975     ],
#          [-118.24      , -117.84495816, -117.44856076, ...,
#            -74.91710675,  -74.44590111,  -73.975     ],
#          [-118.24      , -117.84495816, -117.44856076, ...,
#            -74.91710675,  -74.44590111,  -73.975     ],
#          [-118.24      , -117.84495816, -117.44856076, ...,
#            -74.91710675,  -74.44590111,  -73.975     ],
#          [-118.24      , -117.84495816, -117.44856076, ...,
#  ...
#          [-118.24      , -117.84495816, -117.44856076, ...,
#            -74.91710675,  -74.44590111,  -73.975     ],
#          [-118.24      , -117.84495816, -117.44856076, ...,
#            -74.91710675,  -74.44590111,  -73.975     ],
#          [-118.24      , -117.84495816, -117.44856076, ...,
#            -74.91710675,  -74.44590111,  -73.975     ],
#          [-118.24      , -117.84495816, -117.44856076, ...,
#            -74.91710675,  -74.44590111,  -73.975     ]],
#
#         [[-118.24      , -117.84495816, -117.44856076, ...,
#            -74.91710675,  -74.44590111,  -73.975     ],
#          [-118.24      , -117.84495816, -117.44856076, ...,
#            -74.91710675,  -74.44590111,  -73.975     ],
#          [-118.24      , -117.84495816, -117.44856076, ...,
#            -74.91710675,  -74.44590111,  -73.975     ],
#          [-118.24      , -117.84495816, -117.44856076, ...,
#            -74.91710675,  -74.44590111,  -73.975     ],
#          [-118.24      , -117.84495816, -117.44856076, ...,
#            -74.91710675,  -74.44590111,  -73.975     ]]],
#        shape=(105, 5, 100))
#  Coordinates:
#    * step           (step) float64 840B 0.0 3.0 6.0 9.0 ... 372.0 378.0 384.0
#    * isobaricInhPa  (isobaricInhPa) float64 40B 1e+03 925.0 850.0 700.0 500.0
#    * index          (index) int64 800B 0 1 2 3 4 5 6 7 ... 93 94 95 96 97 98 99
#      longitude      (index) float64 800B -118.2 -117.8 -117.4 ... -74.45 -73.97
#      latitude       (index) float64 800B 34.05 34.2 34.34 ... 40.75 40.73 40.7
#      time           datetime64[ns] 8B 2026-05-17T18:00:00
#      valid_time     datetime64[ns] 8B 2026-05-17T18:00:00
#      meanSea        float64 8B 0.0
#      metpy_crs      object 8B Projection: latitude_longitude
#  Attributes:
#      _metpy_axis:  x,longitude,
#  <xarray.DataArray 'mslp' (step: 105, isobaricInhPa: 5, index: 100)> Size: 210kB
#  dask.array<transpose, shape=(105, 5, 100), dtype=float32, chunksize=(1, 5, 100), chunktype=numpy.ndarray>
#  Coordinates:
#    * step           (step) float64 840B 0.0 3.0 6.0 9.0 ... 372.0 378.0 384.0
#    * isobaricInhPa  (isobaricInhPa) float64 40B 1e+03 925.0 850.0 700.0 500.0
#    * index          (index) int64 800B 0 1 2 3 4 5 6 7 ... 93 94 95 96 97 98 99
#      longitude      (index) float64 800B -118.2 -117.8 -117.4 ... -74.45 -73.97
#      latitude       (index) float64 800B 34.05 34.2 34.34 ... 40.75 40.73 40.7
#      time           datetime64[ns] 8B 2026-05-17T18:00:00
#      valid_time     datetime64[ns] 8B 2026-05-17T18:00:00
#      meanSea        float64 8B 0.0
#      metpy_crs      object 8B Projection: latitude_longitude
#  Attributes: (12/30)
#      GRIB_paramId:                             260074
#      GRIB_dataType:                            fc
#      GRIB_numberOfPoints:                      1038240
#      GRIB_typeOfLevel:                         meanSea
#      GRIB_stepUnits:                           1
#      GRIB_stepType:                            instant
#      ...                                       ...
#      GRIB_name:                                Pressure reduced to MSL
#      GRIB_shortName:                           prmsl
#      GRIB_units:                               Pa
#      long_name:                                Pressure reduced to MSL
#      units:                                    Pa
#      standard_name:                            unknown)

# %% [markdown]
# ## Managing System Memory For Automation
#
# Weather Data files can be quite large and system memory can decrease fast.
#
# The good news is WxData automatically manages system memory!
#
# Old data files are automatically deleted right before downloading a new set of data files.
#
# For extra memory management change the default argument of `clear_recycle_bin=False` to `clear_recycle_bin=True` to clear your recycle/trash bin.
#
# For users who do not wish to clear their recycle bins with each run of the script keep the default `clear_recycle_bin=False`.
